# %% [markdown]
# # test timeAlign

# %%
import matplotlib.pyplot as plt
import numpy as np
from modwt import modwt, modwtmra

# %%
n = 128 
sig = np.zeros(n)
sig[n // 2] = 1
plt.plot(sig)

# %%
lev = 4
w = modwt(sig, 'sym4', lev)
fig, ax = plt.subplots(lev + 1, 1, sharex=True)
for k in range(lev + 1):
    ax[k].plot(w[k])
